# %% [markdown]
# # 06 Business Recommendations
#
# Business focus: convert analysis outputs into actions for pricing, discounts, customer strategy, and regional performance.

# %% [markdown]
# ## Recommendation Framework

# %%
import pandas as pd

recommendations = pd.DataFrame([
    {
        'Insight': 'Some products or sub-categories may generate negative profit.',
        'Evidence': 'Profitability and loss analysis by product and sub-category.',
        'Recommendation': 'Reduce excessive discounts, review supplier cost, or adjust pricing.',
        'Expected Business Impact': 'Improve profit margin and reduce loss leakage.'
    },
    {
        'Insight': 'Revenue concentration may vary by customer segment.',
        'Evidence': 'Segment sales and profit margin analysis.',
        'Recommendation': 'Prioritize retention campaigns for profitable high-value segments.',
        'Expected Business Impact': 'Increase repeat purchases and improve customer lifetime value.'
    },
    {
        'Insight': 'Some regions can have strong sales but weak profitability.',
        'Evidence': 'Region-level sales, profit, and margin analysis.',
        'Recommendation': 'Review regional discount and shipping strategy.',
        'Expected Business Impact': 'Improve regional cost control and sustainable growth.'
    }
])
recommendations
